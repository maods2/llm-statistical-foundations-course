# %% [markdown]
# # 00 · Getting Started — Your First Notebook
#
# ### *Statistical Foundations of Large Language Models*
# **33rd International Biometric Conference (IBC 2026) · Seoul, South Korea**
#
# Welcome! 👋 This short notebook is for participants who have **never used Python or Jupyter notebooks before**. No programming experience is assumed. In about **10 minutes** you will know everything you need to run every activity in this course.
#
# > You are already an expert in statistics — that is the hard part. Running these notebooks is the easy part, and this page walks you through it click by click.

# %% [markdown]
# ## 1. What is a Jupyter notebook?
#
# A **notebook** is a single document that mixes two kinds of content:
#
# - **Text cells** (like the one you are reading now) — explanations, math, and questions.
# - **Code cells** — small pieces of Python that you can *run* to produce a result: a number, a table, or a chart.
#
# You read a notebook **top to bottom**, running each code cell in order, a bit like following a recipe. You do **not** need to write code from scratch — most cells are already written. Your job is to **run them**, **read the output**, and occasionally **change a value** to see what happens.

# %% [markdown]
# ## 2. What is Google Colab (and why we use it)
#
# **Google Colab** is a free website that runs notebooks *in your browser* — nothing to install on your laptop. All you need is a Google account and an internet connection. Colab gives you a temporary computer in the cloud (including, if you want, a free GPU) that already has Python and most libraries ready.
#
# ### How to open a notebook in Colab
#
# 1. Go to **https://colab.research.google.com**
# 2. Choose **File → Upload notebook** and select one of the course `.ipynb` files (for example `01_activity_slides_75_76.ipynb`).
#    - *Or*, if the course files are on GitHub: **File → Open notebook → GitHub tab**, paste the repository link.
# 3. The notebook opens. You are ready to run it.
#
# > 💡 **About the GPU — you do *not* need to do anything now.** Most notebooks in this course run fine on the default free CPU. Only **one** activity (notebook 03, fine-tuning BERT) benefits from a GPU, and that notebook walks you through switching it on, step by step, right where it is needed. So relax and ignore GPUs until then.

# %% [markdown]
# ## 3. How to run a cell
#
# Click on the code cell just below so it is selected, then run it in **any** of these ways:
#
# - Press **Shift + Enter** on your keyboard *(runs the cell and moves to the next one)*, **or**
# - Click the small **▶ (play)** button that appears at the left of the cell.
#
# Try it now on the cell below 👇

# %%
# This is a code cell. The lines starting with '#' are comments — notes for humans
# that Python ignores. Click this cell and press Shift+Enter to run it.

print("Hello, Seoul! My first notebook cell just ran. 🎉")

# %% [markdown]
# Did a message appear directly **underneath** the cell? That text is the **output**. Congratulations — you just ran Python. Everything else in the course works exactly like this.
#
# > While a cell is running you may see a small spinning circle ⟳ or `[*]` at its left. When it finishes, that turns into a number like `[1]`. The number just records the order in which you ran cells.

# %% [markdown]
# ## 4. Python as a calculator (a 60-second tour)
#
# You do not need to learn programming for this course, but three tiny ideas show up everywhere. Run each cell and read the comment.

# %%
# (a) Python does arithmetic. Change the numbers and re-run to experiment.
2 + 3 * 4

# %%
# (b) A 'variable' is just a named box that stores a value for later use.
patients = 1240
events = 119
rate = events / patients        # divide
print("Event rate:", rate)

# %%
# (c) A 'function' is a reusable action. We 'call' it by writing its name and (inputs).
#     round(...) is a built-in function that rounds a number.
print("Rounded rate:", round(rate, 3))

# %% [markdown]
# That is genuinely all the Python you need to recognize. Similarity to formulas you already write in R or elsewhere is intentional.

# %% [markdown]
# ## 5. Text cells vs. code cells (and how to edit)
#
# - A **code cell** has a ▶ play button and runs Python.
# - A **text (Markdown) cell** shows formatted text. **Double-click** a text cell to see its raw form, then press **Shift + Enter** to render it back.
#
# You are encouraged to **edit and experiment**. Changing a value and re-running is the best way to learn — you cannot break anything permanently (see the reset tip below).

# %%
# ✏️ Your turn: change the word "curious" to your own word, then run the cell.
mood = "curious"
print("Today I feel", mood, "about large language models.")

# %% [markdown]
# ## 6. Installing libraries (when a notebook asks)
#
# Python's power comes from **libraries** — collections of ready-made tools (for tables, plots, or AI models). Colab already has most of them. When a notebook needs an extra one, its **first code cell** installs it with a line like:
#
# ```python
# %pip install transformers datasets --quiet
# ```
#
# Just run that cell once. If Colab shows a **"Restart runtime"** button afterward, click it, then continue from the top. That is normal and harmless.

# %%
# Example: this checks that a core scientific library is available.
# (It is pre-installed in Colab, so this should just print a version number.)
import numpy as np
print("NumPy version:", np.__version__)

# %% [markdown]
# ## 7. Reading outputs
#
# Outputs appear right below a cell and come in three common shapes:
#
# - **Text / numbers** — printed results, like the messages above.
# - **Tables** — neat grids of data (produced by a library called *pandas*).
# - **Plots** — charts and figures (produced by *matplotlib*).
#
# Here is a tiny example of a plot so you know what to expect.

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 4, 9, 16, 25]   # x squared

plt.figure(figsize=(5, 3))
plt.plot(x, y, marker="o")
plt.title("A first plot: y = x squared")
plt.xlabel("x"); plt.ylabel("y")
plt.show()

# %% [markdown]
# ## 8. When something goes wrong (it happens to everyone)
#
# If a cell shows a red **error message**, don't worry — errors are a normal part of computing. Try these, in order:
#
# 1. **Re-run the cells above it, from the top.** The most common cause is running cells out of order, so a later cell refers to something an earlier cell hadn't defined yet. In Colab: **Runtime → Run all**.
# 2. **Restart and run again.** **Runtime → Restart runtime**, then **Runtime → Run all**. This clears everything and starts fresh — a clean slate that fixes most problems.
# 3. **Read the last line of the error.** It often names the issue in plain-ish English (e.g. *"NameError: name 'x' is not defined"* means a cell above wasn't run).
# 4. Still stuck? Ask an instructor or a neighbour. You truly cannot damage your computer or the course files.
#
# > 🔑 **The golden rule:** run cells **top to bottom, in order**. About 90% of beginner problems come from skipping a cell.

# %%
# This cell deliberately causes a small error so you can see what one looks like.
# After running it and reading the red message, just move on — nothing is broken.
print(undefined_variable)

# %% [markdown]
# See the `NameError`? It simply means we used a name that was never given a value. Now you'll recognize it if it ever appears for real.

# %% [markdown]
# ## 9. Saving your work
#
# Colab does not change the original course file. To keep your edits and outputs:
#
# - **File → Save a copy in Drive** stores your own version in your Google Drive, **or**
# - **File → Download → Download .ipynb** saves it to your laptop.
#
# Your outputs (numbers, tables, plots) are saved inside the notebook, so you can revisit them later.

# %% [markdown]
# ## 10. You're ready! ✅
#
# Here is the whole workflow you just learned, in one picture:
#
# > **Open in Colab → run cells top to bottom with Shift+Enter → read the output → edit and re-run to explore → restart if stuck.**
#
# ### Recommended order for the course
#
# | # | Notebook | Session | You will build / explore |
# |---|----------|---------|--------------------------|
# | 01 | `01_activity_slides_75_76` | 1 | N-gram language models (counting, perplexity) |
# | 02 | `02_activity_slides_93_94` | 1 | Word embeddings (Word2Vec vs. GloVe) |
# | 03 | `03_activity_slides_192_199` | 2 | Fine-tuning BERT (needs the free GPU) |
# | 04 | `04_activity_slides_252_260` | 2 | Three transformer architectures compared |
# | 05 | `05_session3_prompt_engineering` | 3 | Prompt engineering for biomedical abstracts |
# | 06 | `06_activity_slides_321_323` | 4 | Uncertainty & statistical inference in LLMs |
# | 07 | `07_activity_slides_357_358` | 4 | Watermarking & detecting AI text |
# | 08 | `08_case_study_hallucinations_bias` | 4 | When LLMs go wrong: hallucinations & bias |
#
# Every notebook starts with a short recap of these basics, so you can always jump back if you forget a step.
#
# **Enjoy the course, and welcome to hands-on work with language models!** 🇰🇷
